# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setting up URL

base_url = "https://api.openweathermap.org/data/2.5/weather?"

# %%
# Setting up the loop: weather data will be the array to hold our info, number will serve as a counter for
# the printout, and total is the total number of cities.

weather_data = []
number = 0
total = len(cities)

# Calling the API and putting the required information into a dictionary nested in the array

for city in cities:
    params = {"q": city, "appid": api_key, "units": "imperial"}
    response = requests.get(base_url, params = params)
    data = response.json()
    try:
        weather_data.append({
            "City": data["name"],
            "Cloudiness": data["clouds"]["all"], 
            "Country": data["sys"]["country"], 
            "Date": data["dt"], 
            "Humidity": data["main"]["humidity"], 
            "Lat": data["coord"]["lat"], 
            "Lng": data["coord"]["lon"], 
            "Max Temp": data["main"]["temp_max"], 
            "Wind Speed": data["wind"]["speed"]
        })
        number += 1

        print(f"Processing Record {number} of {len(cities)} | {city}")
        
    except (KeyError):
        print("City not found. Skipping...")
        total = total - 1
        

        continue
# Out:
# Processing Record 1 of 592 | altoona
# Processing Record 2 of 592 | kapaa
# Processing Record 3 of 592 | kyabram
# Processing Record 4 of 592 | niksic
# Processing Record 5 of 592 | kawalu
# Processing Record 6 of 592 | butaritari
# Processing Record 7 of 592 | nanfeng
# Processing Record 8 of 592 | albany
# Processing Record 9 of 592 | marsh harbour
# Processing Record 10 of 592 | nador
# City not found. Skipping...
# Processing Record 11 of 592 | thompson
# Processing Record 12 of 592 | hermanus
# Processing Record 13 of 592 | buenos aires
# City not found. Skipping...
# Processing Record 14 of 592 | hambantota
# Processing Record 15 of 592 | el dorado
# Processing Record 16 of 592 | fontem
# Processing Record 17 of 592 | sistranda
# Processing Record 18 of 592 | georgetown
# Processing Record 19 of 592 | punta arenas
# Processing Record 20 of 592 | katobu
# Processing Record 21 of 592 | leningradskiy
# Processing Record 22 of 592 | cabo san lucas
# Processing Record 23 of 592 | tiksi
# Processing Record 24 of 592 | cape town
# Processing Record 25 of 592 | volga
# Processing Record 26 of 592 | pacific grove
# Processing Record 27 of 592 | mataura
# Processing Record 28 of 592 | bambous virieux
# Processing Record 29 of 592 | pemba
# Processing Record 30 of 592 | ribeira grande
# City not found. Skipping...
# Processing Record 31 of 592 | arlit
# Processing Record 32 of 592 | mitsamiouli
# Processing Record 33 of 592 | nikolskoye
# Processing Record 34 of 592 | jamestown
# Processing Record 35 of 592 | mildura
# Processing Record 36 of 592 | san quintin
# Processing Record 37 of 592 | lagoa
# Processing Record 38 of 592 | victoria
# Processing Record 39 of 592 | vaini
# Processing Record 40 of 592 | shuangcheng
# Processing Record 41 of 592 | grand gaube
# Processing Record 42 of 592 | ushuaia
# Processing Record 43 of 592 | natal
# Processing Record 44 of 592 | tiebissou
# Processing Record 45 of 592 | qaanaaq
# Processing Record 46 of 592 | dikson
# Processing Record 47 of 592 | tasiilaq
# Processing Record 48 of 592 | atuona
# City not found. Skipping...
# Processing Record 49 of 592 | sao miguel do araguaia
# Processing Record 50 of 592 | busselton
# Processing Record 51 of 592 | chicama
# City not found. Skipping...
# Processing Record 52 of 592 | new norfolk
# Processing Record 53 of 592 | quatre cocos
# Processing Record 54 of 592 | solnechnyy
# Processing Record 55 of 592 | sabha
# Processing Record 56 of 592 | port hawkesbury
# Processing Record 57 of 592 | huarmey
# Processing Record 58 of 592 | hofn
# Processing Record 59 of 592 | ilulissat
# City not found. Skipping...
# Processing Record 60 of 592 | arraial do cabo
# Processing Record 61 of 592 | havre-saint-pierre
# Processing Record 62 of 592 | saint george
# Processing Record 63 of 592 | mahebourg
# Processing Record 64 of 592 | hithadhoo
# Processing Record 65 of 592 | hobyo
# Processing Record 66 of 592 | port lincoln
# Processing Record 67 of 592 | puerto ayora
# Processing Record 68 of 592 | oranjemund
# Processing Record 69 of 592 | presidencia roque saenz pena
# Processing Record 70 of 592 | clyde river
# Processing Record 71 of 592 | lavrentiya
# Processing Record 72 of 592 | barrow
# City not found. Skipping...
# Processing Record 73 of 592 | waingapu
# City not found. Skipping...
# Processing Record 74 of 592 | opole lubelskie
# Processing Record 75 of 592 | salalah
# Processing Record 76 of 592 | rikitea
# Processing Record 77 of 592 | praya
# Processing Record 78 of 592 | chokurdakh
# Processing Record 79 of 592 | esperance
# Processing Record 80 of 592 | nakusp
# Processing Record 81 of 592 | hobart
# Processing Record 82 of 592 | hamilton
# Processing Record 83 of 592 | tuktoyaktuk
# Processing Record 84 of 592 | pedro ii
# Processing Record 85 of 592 | faya
# Processing Record 86 of 592 | quelimane
# Processing Record 87 of 592 | hualmay
# Processing Record 88 of 592 | omsukchan
# City not found. Skipping...
# Processing Record 89 of 592 | vestmannaeyjar
# Processing Record 90 of 592 | kendari
# Processing Record 91 of 592 | mahon
# Processing Record 92 of 592 | bluff
# Processing Record 93 of 592 | amga
# Processing Record 94 of 592 | katangli
# Processing Record 95 of 592 | puri
# Processing Record 96 of 592 | fort frances
# Processing Record 97 of 592 | sanmenxia
# Processing Record 98 of 592 | madimba
# City not found. Skipping...
# Processing Record 99 of 592 | iqaluit
# Processing Record 100 of 592 | kifri
# Processing Record 101 of 592 | bredasdorp
# Processing Record 102 of 592 | east london
# Processing Record 103 of 592 | santa barbara
# Processing Record 104 of 592 | tilichiki
# Processing Record 105 of 592 | laguna
# City not found. Skipping...
# Processing Record 106 of 592 | leninskoye
# Processing Record 107 of 592 | lake cowichan
# Processing Record 108 of 592 | bethel
# Processing Record 109 of 592 | codrington
# Processing Record 110 of 592 | port elizabeth
# Processing Record 111 of 592 | businga
# Processing Record 112 of 592 | markova
# Processing Record 113 of 592 | russell
# Processing Record 114 of 592 | suicheng
# Processing Record 115 of 592 | port alfred
# Processing Record 116 of 592 | saldanha
# Processing Record 117 of 592 | nome
# City not found. Skipping...
# Processing Record 118 of 592 | santa isabel do rio negro
# Processing Record 119 of 592 | torbay
# Processing Record 120 of 592 | atambua
# Processing Record 121 of 592 | kodiak
# Processing Record 122 of 592 | millau
# City not found. Skipping...
# Processing Record 123 of 592 | lebu
# City not found. Skipping...
# Processing Record 124 of 592 | hilo
# Processing Record 125 of 592 | lao cai
# Processing Record 126 of 592 | maldonado
# Processing Record 127 of 592 | sioux lookout
# Processing Record 128 of 592 | saint-philippe
# Processing Record 129 of 592 | belaya gora
# Processing Record 130 of 592 | oyama
# Processing Record 131 of 592 | fort nelson
# Processing Record 132 of 592 | kuytun
# Processing Record 133 of 592 | kizukuri
# Processing Record 134 of 592 | cayenne
# Processing Record 135 of 592 | norman wells
# Processing Record 136 of 592 | praia da vitoria
# Processing Record 137 of 592 | beira
# Processing Record 138 of 592 | bhainsdehi
# Processing Record 139 of 592 | aykhal
# Processing Record 140 of 592 | longkou
# Processing Record 141 of 592 | sitka
# Processing Record 142 of 592 | srednekolymsk
# Processing Record 143 of 592 | upernavik
# Processing Record 144 of 592 | zolotyy potik
# Processing Record 145 of 592 | mtwara
# Processing Record 146 of 592 | costinesti
# Processing Record 147 of 592 | muros
# Processing Record 148 of 592 | babu
# Processing Record 149 of 592 | salvador
# City not found. Skipping...
# Processing Record 150 of 592 | xichang
# Processing Record 151 of 592 | patiya
# City not found. Skipping...
# Processing Record 152 of 592 | nyimba
# Processing Record 153 of 592 | ipanema
# Processing Record 154 of 592 | zhigansk
# Processing Record 155 of 592 | tecoanapa
# Processing Record 156 of 592 | mapiri
# Processing Record 157 of 592 | los llanos de aridane
# Processing Record 158 of 592 | lola
# Processing Record 159 of 592 | anadyr
# Processing Record 160 of 592 | yellowknife
# Processing Record 161 of 592 | husavik
# Processing Record 162 of 592 | castro
# Processing Record 163 of 592 | carnarvon
# Processing Record 164 of 592 | poum
# Processing Record 165 of 592 | opuwo
# Processing Record 166 of 592 | buraydah
# Processing Record 167 of 592 | makakilo city
# Processing Record 168 of 592 | mar del plata
# City not found. Skipping...
# Processing Record 169 of 592 | coihaique
# Processing Record 170 of 592 | mehamn
# Processing Record 171 of 592 | cockburn town
# Processing Record 172 of 592 | beloha
# Processing Record 173 of 592 | coquimbo
# Processing Record 174 of 592 | cidreira
# Processing Record 175 of 592 | porbandar
# Processing Record 176 of 592 | tagusao
# Processing Record 177 of 592 | kavieng
# Processing Record 178 of 592 | richards bay
# Processing Record 179 of 592 | gladstone
# Processing Record 180 of 592 | mount gambier
# Processing Record 181 of 592 | umm kaddadah
# Processing Record 182 of 592 | caohai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 183 of 592 | santo antonio do ica
# Processing Record 184 of 592 | zhicheng
# Processing Record 185 of 592 | springfield
# Processing Record 186 of 592 | dingle
# Processing Record 187 of 592 | sri aman
# Processing Record 188 of 592 | sao joao da barra
# City not found. Skipping...
# Processing Record 189 of 592 | abha
# Processing Record 190 of 592 | ancud
# City not found. Skipping...
# Processing Record 191 of 592 | isangel
# Processing Record 192 of 592 | ati
# Processing Record 193 of 592 | chiredzi
# Processing Record 194 of 592 | koshurnikovo
# Processing Record 195 of 592 | sargur
# Processing Record 196 of 592 | rio grande
# Processing Record 197 of 592 | port hardy
# City not found. Skipping...
# Processing Record 198 of 592 | smithers
# Processing Record 199 of 592 | rawson
# Processing Record 200 of 592 | ust-maya
# Processing Record 201 of 592 | avarua
# Processing Record 202 of 592 | tromso
# Processing Record 203 of 592 | zabid
# Processing Record 204 of 592 | ahipara
# City not found. Skipping...
# Processing Record 205 of 592 | irbeyskoye
# City not found. Skipping...
# Processing Record 206 of 592 | khatanga
# Processing Record 207 of 592 | provideniya
# Processing Record 208 of 592 | progreso
# Processing Record 209 of 592 | noormarkku
# Processing Record 210 of 592 | plettenberg bay
# Processing Record 211 of 592 | hasaki
# Processing Record 212 of 592 | panalingaan
# Processing Record 213 of 592 | chuy
# Processing Record 214 of 592 | nelson bay
# City not found. Skipping...
# Processing Record 215 of 592 | oksfjord
# Processing Record 216 of 592 | norfolk
# City not found. Skipping...
# Processing Record 217 of 592 | cherskiy
# Processing Record 218 of 592 | kumluca
# Processing Record 219 of 592 | san juan
# Processing Record 220 of 592 | luderitz
# Processing Record 221 of 592 | nassau
# Processing Record 222 of 592 | oranjestad
# Processing Record 223 of 592 | caravelas
# Processing Record 224 of 592 | nemuro
# Processing Record 225 of 592 | podor
# Processing Record 226 of 592 | gboko
# Processing Record 227 of 592 | puerto lempira
# Processing Record 228 of 592 | luangwa
# Processing Record 229 of 592 | dhidhdhoo
# Processing Record 230 of 592 | vostok
# Processing Record 231 of 592 | mujiayingzi
# Processing Record 232 of 592 | havelock
# Processing Record 233 of 592 | draguignan
# Processing Record 234 of 592 | maymyo
# City not found. Skipping...
# Processing Record 235 of 592 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 236 of 592 | caruray
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 237 of 592 | muroto
# City not found. Skipping...
# Processing Record 238 of 592 | tlacotepec
# Processing Record 239 of 592 | maniitsoq
# Processing Record 240 of 592 | belyy yar
# Processing Record 241 of 592 | ozerki
# Processing Record 242 of 592 | kristiansund
# Processing Record 243 of 592 | greenwood
# Processing Record 244 of 592 | shubarshi
# Processing Record 245 of 592 | chapais
# Processing Record 246 of 592 | cross lanes
# City not found. Skipping...
# Processing Record 247 of 592 | pulwama
# Processing Record 248 of 592 | kerman
# Processing Record 249 of 592 | presidente medici
# Processing Record 250 of 592 | touros
# Processing Record 251 of 592 | byron bay
# Processing Record 252 of 592 | kieta
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 253 of 592 | constitucion
# Processing Record 254 of 592 | narsaq
# Processing Record 255 of 592 | kaitangata
# Processing Record 256 of 592 | kaniama
# Processing Record 257 of 592 | matamoros
# Processing Record 258 of 592 | alofi
# Processing Record 259 of 592 | sangar
# Processing Record 260 of 592 | souillac
# Processing Record 261 of 592 | pevek
# Processing Record 262 of 592 | lucapa
# Processing Record 263 of 592 | evensk
# Processing Record 264 of 592 | nizhnevartovsk
# Processing Record 265 of 592 | shetpe
# Processing Record 266 of 592 | te anau
# Processing Record 267 of 592 | ponta do sol
# Processing Record 268 of 592 | ostersund
# Processing Record 269 of 592 | nishihara
# Processing Record 270 of 592 | qaqortoq
# Processing Record 271 of 592 | kankaanpaa
# Processing Record 272 of 592 | aksarka
# Processing Record 273 of 592 | yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 274 of 592 | price
# Processing Record 275 of 592 | ngunguru
# Processing Record 276 of 592 | mayo
# Processing Record 277 of 592 | belmonte
# Processing Record 278 of 592 | lubbock
# Processing Record 279 of 592 | hirara
# City not found. Skipping...
# Processing Record 280 of 592 | taoudenni
# Processing Record 281 of 592 | tsaratanana
# Processing Record 282 of 592 | gravdal
# Processing Record 283 of 592 | san patricio
# Processing Record 284 of 592 | florianopolis
# Processing Record 285 of 592 | diffa
# Processing Record 286 of 592 | yunyang
# City not found. Skipping...
# Processing Record 287 of 592 | itoman
# Processing Record 288 of 592 | boca do acre
# Processing Record 289 of 592 | ban nahin
# Processing Record 290 of 592 | katsuura
# Processing Record 291 of 592 | nhulunbuy
# Processing Record 292 of 592 | cardston
# Processing Record 293 of 592 | ximei
# Processing Record 294 of 592 | bayangol
# Processing Record 295 of 592 | spineni
# Processing Record 296 of 592 | deputatskiy
# Processing Record 297 of 592 | aracaju
# Processing Record 298 of 592 | yalutorovsk
# Processing Record 299 of 592 | fairbanks
# Processing Record 300 of 592 | hovd
# Processing Record 301 of 592 | hami
# Processing Record 302 of 592 | dunedin
# Processing Record 303 of 592 | lima
# Processing Record 304 of 592 | okhotsk
# Processing Record 305 of 592 | severo-kurilsk
# Processing Record 306 of 592 | dumas
# Processing Record 307 of 592 | nicoya
# City not found. Skipping...
# Processing Record 308 of 592 | baykit
# Processing Record 309 of 592 | klaksvik
# Processing Record 310 of 592 | port hedland
# Processing Record 311 of 592 | jining
# Processing Record 312 of 592 | yumen
# City not found. Skipping...
# Processing Record 313 of 592 | vardo
# Processing Record 314 of 592 | nanortalik
# Processing Record 315 of 592 | faanui
# Processing Record 316 of 592 | saint-joseph
# Processing Record 317 of 592 | mastic beach
# Processing Record 318 of 592 | stephenville
# Processing Record 319 of 592 | parabel
# City not found. Skipping...
# Processing Record 320 of 592 | sao felix do xingu
# Processing Record 321 of 592 | filingue
# Processing Record 322 of 592 | muravlenko
# City not found. Skipping...
# Processing Record 323 of 592 | grafton
# Processing Record 324 of 592 | meadow lake
# Processing Record 325 of 592 | tselinnoye
# Processing Record 326 of 592 | geraldton
# Processing Record 327 of 592 | ayr
# Processing Record 328 of 592 | namtsy
# City not found. Skipping...
# Processing Record 329 of 592 | avera
# Processing Record 330 of 592 | karratha
# Processing Record 331 of 592 | longyearbyen
# Processing Record 332 of 592 | huilong
# Processing Record 333 of 592 | gat
# Processing Record 334 of 592 | imbituba
# Processing Record 335 of 592 | neuquen
# Processing Record 336 of 592 | ibia
# Processing Record 337 of 592 | mangan
# Processing Record 338 of 592 | ternate
# Processing Record 339 of 592 | manthani
# Processing Record 340 of 592 | viransehir
# Processing Record 341 of 592 | saint-louis
# Processing Record 342 of 592 | juan lacaze
# City not found. Skipping...
# Processing Record 343 of 592 | aranos
# Processing Record 344 of 592 | alice springs
# Processing Record 345 of 592 | kalakamati
# Processing Record 346 of 592 | saint-francois
# Processing Record 347 of 592 | port augusta
# Processing Record 348 of 592 | lithgow
# Processing Record 349 of 592 | dongsheng
# City not found. Skipping...
# Processing Record 350 of 592 | stokmarknes
# Processing Record 351 of 592 | adrar
# Processing Record 352 of 592 | kampar
# City not found. Skipping...
# Processing Record 353 of 592 | bubaque
# Processing Record 354 of 592 | nyurba
# Processing Record 355 of 592 | san pedro
# City not found. Skipping...
# Processing Record 356 of 592 | daura
# Processing Record 357 of 592 | senanga
# Processing Record 358 of 592 | rafsanjan
# Processing Record 359 of 592 | sept-iles
# Processing Record 360 of 592 | amapa
# Processing Record 361 of 592 | sompeta
# Processing Record 362 of 592 | saint-pierre
# Processing Record 363 of 592 | mount isa
# Processing Record 364 of 592 | kralendijk
# Processing Record 365 of 592 | southbridge
# Processing Record 366 of 592 | ouadda
# Processing Record 367 of 592 | blanquefort
# Processing Record 368 of 592 | lata
# Processing Record 369 of 592 | abalak
# Processing Record 370 of 592 | valparai
# Processing Record 371 of 592 | tulun
# Processing Record 372 of 592 | shimoda
# Processing Record 373 of 592 | puerto carreno
# City not found. Skipping...
# Processing Record 374 of 592 | gori
# City not found. Skipping...
# Processing Record 375 of 592 | tautira
# Processing Record 376 of 592 | kjopsvik
# Processing Record 377 of 592 | ambulu
# City not found. Skipping...
# Processing Record 378 of 592 | yeppoon
# Processing Record 379 of 592 | vila
# City not found. Skipping...
# Processing Record 380 of 592 | caldas novas
# Processing Record 381 of 592 | celestun
# Processing Record 382 of 592 | sambava
# Processing Record 383 of 592 | myitkyina
# Processing Record 384 of 592 | singaraja
# Processing Record 385 of 592 | turbat
# Processing Record 386 of 592 | mount pleasant
# Processing Record 387 of 592 | tazovskiy
# Processing Record 388 of 592 | honiara
# Processing Record 389 of 592 | warri
# Processing Record 390 of 592 | rio gallegos
# Processing Record 391 of 592 | saint-augustin
# Processing Record 392 of 592 | colombo
# Processing Record 393 of 592 | acapulco
# Processing Record 394 of 592 | sochi
# Processing Record 395 of 592 | le port
# Processing Record 396 of 592 | dakar
# Processing Record 397 of 592 | brae
# City not found. Skipping...
# Processing Record 398 of 592 | whitianga
# Processing Record 399 of 592 | lobito
# City not found. Skipping...
# Processing Record 400 of 592 | macapa
# Processing Record 401 of 592 | atasu
# Processing Record 402 of 592 | kruisfontein
# Processing Record 403 of 592 | taltal
# Processing Record 404 of 592 | montanha
# Processing Record 405 of 592 | grenada
# Processing Record 406 of 592 | soto la marina
# Processing Record 407 of 592 | les cayes
# Processing Record 408 of 592 | pangnirtung
# Processing Record 409 of 592 | inirida
# Processing Record 410 of 592 | boa vista
# Processing Record 411 of 592 | culaman
# Processing Record 412 of 592 | hanna
# Processing Record 413 of 592 | fortuna
# Processing Record 414 of 592 | khorinsk
# Processing Record 415 of 592 | coos bay
# Processing Record 416 of 592 | ewa beach
# City not found. Skipping...
# Processing Record 417 of 592 | bonthe
# Processing Record 418 of 592 | sorland
# Processing Record 419 of 592 | nizhniy kuranakh
# Processing Record 420 of 592 | fare
# Processing Record 421 of 592 | rocha
# Processing Record 422 of 592 | tall kayf
# Processing Record 423 of 592 | coron
# Processing Record 424 of 592 | birao
# Processing Record 425 of 592 | salekhard
# Processing Record 426 of 592 | iralaya
# Processing Record 427 of 592 | portland
# Processing Record 428 of 592 | kyenjojo
# Processing Record 429 of 592 | tveit
# Processing Record 430 of 592 | san antonio
# Processing Record 431 of 592 | formosa do rio preto
# Processing Record 432 of 592 | tessalit
# City not found. Skipping...
# Processing Record 433 of 592 | inhambane
# Processing Record 434 of 592 | juneau
# Processing Record 435 of 592 | butembo
# Processing Record 436 of 592 | tuatapere
# Processing Record 437 of 592 | simpang
# Processing Record 438 of 592 | monte alegre
# Processing Record 439 of 592 | pahrump
# Processing Record 440 of 592 | velsk
# Processing Record 441 of 592 | arona
# Processing Record 442 of 592 | eureka
# City not found. Skipping...
# Processing Record 443 of 592 | parsabad
# City not found. Skipping...
# Processing Record 444 of 592 | coro
# Processing Record 445 of 592 | waipawa
# Processing Record 446 of 592 | yuncheng
# Processing Record 447 of 592 | luba
# Processing Record 448 of 592 | nizhniy tsasuchey
# Processing Record 449 of 592 | sola
# Processing Record 450 of 592 | corner brook
# Processing Record 451 of 592 | kavaratti
# City not found. Skipping...
# Processing Record 452 of 592 | puga
# City not found. Skipping...
# Processing Record 453 of 592 | talcahuano
# Processing Record 454 of 592 | tateyama
# Processing Record 455 of 592 | aswan
# Processing Record 456 of 592 | ende
# Processing Record 457 of 592 | carbonia
# Processing Record 458 of 592 | calama
# Processing Record 459 of 592 | tabou
# City not found. Skipping...
# Processing Record 460 of 592 | road town
# Processing Record 461 of 592 | guerrero negro
# Processing Record 462 of 592 | yerbogachen
# Processing Record 463 of 592 | virginia beach
# Processing Record 464 of 592 | marawi
# Processing Record 465 of 592 | airai
# Processing Record 466 of 592 | magadan
# Processing Record 467 of 592 | noumea
# Processing Record 468 of 592 | polson
# Processing Record 469 of 592 | iquique
# Processing Record 470 of 592 | aklavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 471 of 592 | gazli
# Processing Record 472 of 592 | isla mujeres
# Processing Record 473 of 592 | talnakh
# City not found. Skipping...
# Processing Record 474 of 592 | boa viagem
# Processing Record 475 of 592 | nampula
# Processing Record 476 of 592 | songjianghe
# Processing Record 477 of 592 | oktyabrskiy
# Processing Record 478 of 592 | adilabad
# Processing Record 479 of 592 | conceicao do araguaia
# Processing Record 480 of 592 | la grande
# City not found. Skipping...
# Processing Record 481 of 592 | northam
# Processing Record 482 of 592 | cabra
# Processing Record 483 of 592 | antsohihy
# Processing Record 484 of 592 | axim
# Processing Record 485 of 592 | svetlogorsk
# Processing Record 486 of 592 | vila velha
# Processing Record 487 of 592 | monroe
# Processing Record 488 of 592 | maragogi
# Processing Record 489 of 592 | mocajuba
# Processing Record 490 of 592 | tres arroyos
# Processing Record 491 of 592 | machico
# City not found. Skipping...
# Processing Record 492 of 592 | kangaatsiaq
# Processing Record 493 of 592 | emba
# Processing Record 494 of 592 | ugoofaaru
# Processing Record 495 of 592 | garowe
# Processing Record 496 of 592 | orlik
# Processing Record 497 of 592 | pacifica
# Processing Record 498 of 592 | grenaa
# Processing Record 499 of 592 | kolbermoor
# City not found. Skipping...
# Processing Record 500 of 592 | rupnagar
# Processing Record 501 of 592 | idlib
# Processing Record 502 of 592 | viytivka
# Processing Record 503 of 592 | kiunga
# Processing Record 504 of 592 | ocos
# City not found. Skipping...
# Processing Record 505 of 592 | terrace
# Processing Record 506 of 592 | zaragoza
# Processing Record 507 of 592 | randolph
# City not found. Skipping...
# Processing Record 508 of 592 | marabba
# City not found. Skipping...
# Processing Record 509 of 592 | birjand
# Processing Record 510 of 592 | rosario
# Processing Record 511 of 592 | palestine
# Processing Record 512 of 592 | kingman
# Processing Record 513 of 592 | basoko
# Processing Record 514 of 592 | lompoc
# Processing Record 515 of 592 | khorramshahr
# Processing Record 516 of 592 | bani
# Processing Record 517 of 592 | tanout
# Processing Record 518 of 592 | barcelos
# Processing Record 519 of 592 | lazaro cardenas
# Processing Record 520 of 592 | stillwater
# City not found. Skipping...
# Processing Record 521 of 592 | zalantun

# %%
df = pd.DataFrame(weather_data)
df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv("cities.csv", index = False)

# %%
file = pd.read_csv("cities.csv")

# %%
# Finding the date and converting it to usable form

date = np.array(df["Date"])
date = time.ctime(date[0])

# String slicing to get month, day, year

m = month[4:7]
day = date[8:10]
year = month[20:]

# Creating date variable to put into graphs

date = f"{m} {day}, {year}"
date
# Out:
# 'Aug 27, 2019'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
ax.scatter(y=df["Max Temp"], x=df["Lat"], marker="o", facecolors="steelblue", edgecolors="black")

# Title, Labela
ax.set_title(f'City Latitude vs. Max Temperature ({date})', fontdict={'size':12})
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")

plt.savefig("Max Temp.jpeg")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.scatter(y=df["Humidity"], x=df["Lat"], marker="o", facecolors="steelblue", edgecolors="black")

# Title, Labela
ax.set_title(f'City Latitude vs. Humidity ({date})', fontdict={'size':12})
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity")

plt.savefig("Humidity.jpeg")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.scatter(y=df["Cloudiness"], x=df["Lat"], marker="o", facecolors="steelblue", edgecolors="black")

# Title, Labela
ax.set_title(f'City Latitude vs. Cloudiness ({date})', fontdict={'size':12})
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness")

plt.savefig("Cloudiness.jpeg")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(y=df["Wind Speed"], x=df["Lat"], marker="o", facecolors="steelblue", edgecolors="black")

# Title, Labela
ax.set_title(f'City Latitude vs. Wind Speed ({date})', fontdict={'size':12})
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed")

plt.savefig("Wind Speed.jpeg")

plt.show()

# %% [markdown]
# # Analysis of Observable Trends
#
# 1) Wind speed appears to average somewhere between 5 - 10 mph, which seems pretty normal. The few outliers are probably experiencing storms.
#
# 2) There doesn't appear to be any correlation between latitude and cloudiness, although the apparent horizontal striation of the plot is sort of interesting in itself. There aren't many clouds as towns approach the poles. Hole in the ozone layer? Maybe, but it more probably represents the lack of information from those latitudes. There aren't many towns near the poles, so weather information from this data service isn't available.
#
# 3) Max temperature very nicely mimics the shape of the earth, supporting the claim that as the earth bulges towards the equator the temperature rises. The outliers are in the 30 - 50 range of the parallels -- not surprising, as it's currently summer in the northern hemisphere and those latitudes are closest to the sun thanks to the earth's tilt.
#
# # Conclusion
#
# The dataset has two limitations. One is lack of information for a significant number of small towns, which turned out to be 13.6% of the towns I generated with these random coordinates. In a world that's western-centric, I suspect the missing data may come from the African and South American continents. I didn't confirm this, though.
#
# The second limitation is that this weather source can access current weather only for the 1/3 of earth's surface not covered by water. The likelihood of catching some tiny Pacific islands with these randomly generated geo-coordinates is low, so we won't be getting much information that's not coming from the six inhabited continents. If the 13.6% loss of information from towns on dry land that don't have weather stations is representative of any potential dataset, then we're getting access to weather from only about 29% of the earth's surface. And that's still a large overestimate because we'll never get geocoordinates that match a town near one of the poles since those towns don't exist.
#
# Is humidity over the oceans higher since there's more water directly in contact with the air? Is air temperature lower for the same reason? Are winds higher in speed without land obstructions? Or slower because the temperature differential between surface and air is less extreme? Are there more clouds over water or not? None of these questions is answerable with the data available. Based on what we've got, the claim about temperature being related to latitude seems to hold up. It doesn't appear to be influenced by clouds, wind, or humidity, which all look pretty consistent across all latitudes.
